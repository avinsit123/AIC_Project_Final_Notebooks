# %%
import openfl.native as fx
from openfl.federated import FederatedModel, FederatedDataSet
from openfl.utilities.optimizers.torch import FedProxOptimizer

# %% [markdown]
# ## Load Dataset and Transfer
# ### Define Torch Dataloader

# %%
from openfl.federated import FederatedModel,FederatedDataSet

from openfl.utilities.data_splitters import DirichletNumPyDataSplitter
from openfl.utilities.data_splitters import EqualNumPyDataSplitter
from openfl.utilities.data_splitters import LogNormalNumPyDataSplitter
from openfl.utilities.data_splitters import RandomNumPyDataSplitter

import DataSplitterMethods
data_splitter = DataSplitterMethods.SplitFunctionGenerator("4-Class-per-collab-Split")

import torch
import torchvision
from torchvision import transforms
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

## Replace here with path of your folder. 
dataset = torchvision.datasets.ImageFolder(root='/home/shivam/Documents/Gatech_Coursework/Semester 2/AIC/Final Project/content/gaussian_filtered_images/gaussian_filtered_images', transform=transform)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True, num_workers=4)

# %%
print(data_splitter)

# %% [markdown]
# ### Display data into train and valid sets

# %%
import matplotlib.pyplot as plt
import numpy as np

def index_to_class_name(index, dataset):
    return dataset.classes[index]

len_images = 10
images, labels = next(iter(dataloader))
sample_indices = np.random.choice(len(images), len_images, replace=False)
sample_images = images[sample_indices]
sample_labels = labels[sample_indices]

for i, image in enumerate(sample_images):
    class_name = index_to_class_name(sample_labels[i], dataset)
    plt.subplot(2, 5, i+1)
    plt.imshow(image.permute(1, 2, 0))
    plt.title(class_name)
    plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Distribute data into train and valid data sets

# %%
data_loader = torch.utils.data.DataLoader(dataset, batch_size=len(dataset), shuffle=False)
data, labels = next(iter(data_loader))
print("The data shape is {}".format(data.shape))
# Out:
# The data shape is torch.Size([3662, 3, 224, 224])

# %%
import torch.nn.functional as F
def split_and_return_train_valid(data, labels, split = 0.2):
  test_indices = np.random.rand(data.shape[0]) < split
  train_indices = ~test_indices
  train_data, test_data = data[train_indices], data[test_indices]
  train_labels, test_labels = labels[train_indices], labels[test_indices]
  train_labels, test_labels = F.one_hot(train_labels), F.one_hot(test_labels)
  return train_data, train_labels, test_data, test_labels

train_data, train_labels, test_data, test_labels = split_and_return_train_valid(data, labels) 
print("Train Data Length is {}".format(len(train_data)))
print("Test Data Length is {}".format(len(test_data)))
# Out:
# Train Data Length is 2934
# Test Data Length is 728

# %%
from openfl.federated import FederatedModel,FederatedDataSet
batch_size = 16
num_classes = 5
fl_data = FederatedDataSet(train_data, train_labels, test_data, test_labels, 
                           batch_size = batch_size , num_classes = num_classes, train_splitter = EqualNumPyDataSplitter())

# %% [markdown]
# ###  Define Model - Pretrained Model FedAVG
# We can use a pretrained model like Inception or VGG Net to perform classification. These have already been pretrained on large-scale image data and we need to train only some final linear layers.

# %%
import torch
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim

class InceptionV1(nn.Module):
    def __init__(self, num_classes=5):
        super(InceptionV1, self).__init__()
        self.num_classes = num_classes
        self.inception = models.googlenet(pretrained=True)
        
        for param in self.inception.parameters():
            param.requires_grad = False
            
        self.inception.fc = nn.Linear(self.inception.fc.in_features, num_classes)

    def forward(self, x):
        x = self.inception(x)
        return F.log_softmax(x, dim=1)
    
#     def train_epoch(self, batch_generator):
#         from openfl.federated.task import PyTorchTaskRunner
#         self.optimizer.set_old_weights([p for p in self.parameters()])
#         return PyTorchTaskRunner.train_epoch(self, batch_generator)
    
optimizer = lambda x: optim.Adam(x, lr=1e-4)

def cross_entropy(output, target):
    """Binary cross-entropy metric
    """
    return F.binary_cross_entropy_with_logits(input=output,target=target.float())

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

count_parameters(InceptionV1())

## Earlier Parameters: 51386181
# Out:
# /home/shivam/.local/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/shivam/.local/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=GoogLeNet_Weights.IMAGENET1K_V1`. You can also use `weights=GoogLeNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 5125

# %%
net = InceptionV1()
net(data[3:8]).shape
# Out:
# torch.Size([5, 5])

# %%
fl_model = FederatedModel(build_model=InceptionV1, optimizer=optimizer, loss_fn=cross_entropy, data_loader=fl_data)
# Out:
# tried to remove tensor: __opt_state_needed not present in the tensor dict

# %% [markdown]
# ### Define OpenFlow Plan

# %%
NUM_COLLABORATORS = 5
collaborator_list = [str(i) for i in range(NUM_COLLABORATORS)]
experiment_collaborators = {col_name:col_model for col_name, col_model \
                                 in zip(collaborator_list, fl_model.setup(len(collaborator_list)))}
# Out:
# tried to remove tensor: __opt_state_needed not present in the tensor dict
# tried to remove tensor: __opt_state_needed not present in the tensor dict
# tried to remove tensor: __opt_state_needed not present in the tensor dict
# tried to remove tensor: __opt_state_needed not present in the tensor dict
# tried to remove tensor: __opt_state_needed not present in the tensor dict

# %%
fx.init('torch_cnn_mnist', col_names=collaborator_list)
# Out:
# Creating Workspace Directories
# Creating Workspace Templates
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch==1.13.1 in /home/shivam/.local/lib/python3.8/site-packages (from -r /home/shivam/.local/workspace/requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: torchvision==0.14.1 in /home/shivam/.local/lib/python3.8/site-packages (from -r /home/shivam/.local/workspace/requirements.txt (line 2)) (0.14.1)
# Requirement already satisfied: tensorboard in /home/shivam/.local/lib/python3.8/site-packages (from -r /home/shivam/.local/workspace/requirements.txt (line 3)) (2.8.0)
# Requirement already satisfied: wheel>=0.38.0 in /home/shivam/.local/lib/python3.8/site-packages (from -r /home/shivam/.local/workspace/requirements.txt (line 4)) (0.40.0)
# Requirement already satisfied: typing-extensions in /home/shivam/.local/lib/python3.8/site-packages (from torch==1.13.1->-r /home/shivam/.local/workspace/requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.8/dist-packages (from torch==1.13.1->-r /home/shivam/.local/workspace/requirements.txt (line 1)) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.8/dist-packages (from torch==1.13.1->-r /home/shivam/.local/workspace/requirements.txt (line 1)) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.8/dist-packages (from torch==1.13.1->-r /home/shivam/.local/workspace/requirements.txt (line 1)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.8/dist-packages (from torch==1.13.1->-r /home/shivam/.local/workspace/requirements.txt (line 1)) (11.7.99)
# Requirement already satisfied: numpy in /home/shivam/.local/lib/python3.8/site-packages (from torchvision==0.14.1->-r /home/shivam/.local/workspace/requirements.txt (line 2)) (1.22.2)
# Requirement already satisfied: requests in /home/shivam/.local/lib/python3.8/site-packages (from torchvision==0.14.1->-r /home/shivam/.local/workspace/requirements.txt (line 2)) (2.28.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/shivam/.local/lib/python3.8/site-packages (from torchvision==0.14.1->-r /home/shivam/.local/workspace/requirements.txt (line 2)) (9.4.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->-r /home/shivam/.local/workspace/requirements.txt (line 1)) (45.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (2.17.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (1.48.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (3.4.3)
# Requirement already satisfied: protobuf>=3.6.0 in /home/shivam/.local/lib/python3.8/site-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (3.20.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/shivam/.local/lib/python3.8/site-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/shivam/.local/lib/python3.8/site-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/shivam/.local/lib/python3.8/site-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/shivam/.local/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (4.12.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->torchvision==0.14.1->-r /home/shivam/.local/workspace/requirements.txt (line 2)) (2.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/shivam/.local/lib/python3.8/site-packages (from requests->torchvision==0.14.1->-r /home/shivam/.local/workspace/requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/shivam/.local/lib/python3.8/site-packages (from requests->torchvision==0.14.1->-r /home/shivam/.local/workspace/requirements.txt (line 2)) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->torchvision==0.14.1->-r /home/shivam/.local/workspace/requirements.txt (line 2)) (2019.11.28)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/shivam/.local/lib/python3.8/site-packages (from werkzeug>=0.11.15->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/shivam/.local/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (3.1.0)
# Successfully installed packages from /home/shivam/.local/workspace/requirements.txt.
#
# New workspace directory structure:
# workspace
# ├── envoy_config.yaml
# ├── cert
# ├── test_output
# ├── agg_to_col_3_signed_cert.zip
# ├── spam_metric.log
# ├── agg_to_col_1_signed_cert.zip
# ├── agg_to_col_4_signed_cert.zip
# ├── shard_descriptor.py
# ├── save
# │   ├── torch_cnn_mnist_init.pbuf
# │   ├── keras_cnn_mnist_init.pbuf
# │   ├── torch_cnn_mnist_last.pbuf
# │   └── torch_cnn_mnist_best.pbuf
# ├── logs
# │   └── cnn_mnist
# │       ├── events.out.tfevents.1681513600.Roger.50728.0
# │       ├── events.out.tfevents.1681315750.Roger.48608.0
# │       ├── events.out.tfevents.1681431847.Roger.17954.0
# │       ├── events.out.tfevents.1681434736.Roger.21857.0
# │       ├── events.out.tfevents.1681514476.Roger.52085.0
# │       ├── events.out.tfevents.1681512387.Roger.43871.0
# │       ├── events.out.tfevents.1681519569.Roger.59873.0
# │       ├── events.out.tfevents.1681269401.Roger.8557.0
# │       ├── events.out.tfevents.1681442737.Roger.16494.0
# │       ├── events.out.tfevents.1681500355.Roger.36072.0
# │       ├── events.out.tfevents.1681504902.Roger.43395.0
# │       ├── events.out.tfevents.1681433866.Roger.20887.0
# │       ├── events.out.tfevents.1681518873.Roger.58996.0
# │       ├── events.out.tfevents.1681433027.Roger.19981.0
# │       ├── events.out.tfevents.1681269659.Roger.9184.0
# │       ├── events.out.tfevents.1681514439.Roger.43369.0
# │       ├── events.out.tfevents.1681270907.Roger.12430.0
# │       ├── events.out.tfevents.1681515196.Roger.52877.0
# │       ├── events.out.tfevents.1681442137.Roger.16260.0
# │       ├── events.out.tfevents.1681516050.Roger.55083.0
# │       ├── events.out.tfevents.1681529604.Roger.62329.0
# │       ├── events.out.tfevents.1681431623.Roger.15620.0
# │       ├── events.out.tfevents.1680565291.Roger.63976.0
# │       ├── events.out.tfevents.1681431104.Roger.15376.0
# │       ├── events.out.tfevents.1681431169.Roger.15821.0
# │       ├── events.out.tfevents.1681530171.Roger.62643.0
# │       ├── events.out.tfevents.1681512958.Roger.50296.0
# │       ├── events.out.tfevents.1681270134.Roger.10870.0
# │       ├── events.out.tfevents.1681438729.Roger.8889.0
# │       ├── events.out.tfevents.1681267520.Roger.21655.0
# │       ├── events.out.tfevents.1681431926.Roger.18157.0
# │       ├── events.out.tfevents.1680564705.Roger.56398.2
# │       ├── events.out.tfevents.1681517475.Roger.57469.0
# │       ├── events.out.tfevents.1681434171.Roger.21460.0
# │       ├── events.out.tfevents.1680564647.Roger.56398.1
# │       ├── events.out.tfevents.1681431293.Roger.16283.0
# │       ├── events.out.tfevents.1681437192.Roger.21359.0
# │       ├── events.out.tfevents.1681435916.Roger.22846.0
# │       ├── events.out.tfevents.1681501080.Roger.37298.0
# │       ├── events.out.tfevents.1681432490.Roger.19002.0
# │       ├── events.out.tfevents.1681431373.Roger.16522.0
# │       ├── events.out.tfevents.1681518143.Roger.58198.0
# │       ├── events.out.tfevents.1681514126.Roger.51532.0
# │       ├── events.out.tfevents.1681271675.Roger.8617.0
# │       ├── events.out.tfevents.1681266567.Roger.17464.0
# │       ├── events.out.tfevents.1681431242.Roger.15109.0
# │       ├── events.out.tfevents.1681333861.Roger.6627.0
# │       ├── events.out.tfevents.1681512812.Roger.47787.0
# │       ├── events.out.tfevents.1681437951.Roger.8909.0
# │       ├── events.out.tfevents.1681520185.Roger.52115.0
# │       ├── events.out.tfevents.1681516946.Roger.56642.0
# │       ├── events.out.tfevents.1681267303.Roger.19209.0
# │       └── events.out.tfevents.1681440192.Roger.9897.0
# ├── director.yaml
# ├── agg_to_col_one_signed_cert.zip
# ├── src
# │   ├── pt_cnn.py
# │   ├── tfmnist_inmemory.py
# │   ├── mnist_utils.py
# │   ├── keras_cnn.py
# │   ├── __init__.py
# │   ├── ptmnist_inmemory.py
# │   └── __pycache__
# │       ├── __init__.cpython-38.pyc
# │       └── mnist_utils.cpython-38.pyc
# ├── agg_to_col_0_signed_cert.zip
# ├── agg_to_col_2_signed_cert.zip
# ├── .workspace
# ├── requirements.txt
# ├── data
# ├── plan
# │   ├── defaults
# │   ├── data.yaml
# │   ├── plan.yaml
# │   └── cols.yaml
# └── agg_to_col_two_signed_cert.zip
#
# 8 directories, 83 files
# Setting Up Certificate Authority...
#
# 1.  Create Root CA
# 1.1 Create Directories
# 1.2 Create Database
# 1.3 Create CA Request and Certificate
# 2.  Create Signing Certificate
# 2.1 Create Directories
# 2.2 Create Database
# 2.3 Create Signing Certificate CSR
# 2.4 Sign Signing Certificate CSR
# 3   Create Certificate Chain
#
# Done.
# Creating AGGREGATOR certificate key pair with following settings: CN=roger, SAN=DNS:roger
#   Writing AGGREGATOR certificate key pair to: /home/shivam/Documents/Gatech_Coursework/Semester 2/AIC/Final Project/git/AIC_Project_Final_Notebooks/OpenFl/cert/server
# The CSR Hash for file server/agg_roger.csr = 7a49751da771612cd4595ba95198c54ba99a3ecf42adbece87782691e9fb276832a51777caa32266247f70643650a47e
#  Signing AGGREGATOR certificate
# Creating COLLABORATOR certificate key pair with following settings: CN=0, SAN=DNS:0
#   Moving COLLABORATOR certificate to: /home/shivam/Documents/Gatech_Coursework/Semester 2/AIC/Final Project/git/AIC_Project_Final_Notebooks/OpenFl/cert/col_0
# The CSR Hash for file col_0.csr = 9594886dc364def83f1844c248a9ba907995c1d6b4306f2f7c0de61345477473a587e0ba9dee8bb83cd2878574974017
#  Signing COLLABORATOR certificate
#
# Registering 0 in /home/shivam/.local/workspace/plan/cols.yaml
# Creating COLLABORATOR certificate key pair with following settings: CN=1, SAN=DNS:1
#   Moving COLLABORATOR certificate to: /home/shivam/Documents/Gatech_Coursework/Semester 2/AIC/Final Project/git/AIC_Project_Final_Notebooks/OpenFl/cert/col_1
# The CSR Hash for file col_1.csr = f5b7c7ccff55e46f8432afa5c5b0ebd2a8414eba848a8b4714f07600f28c33b5a0e7f84d56a8e830d54e05d5ec02a7cb
#  Signing COLLABORATOR certificate
#
# Registering 1 in /home/shivam/.local/workspace/plan/cols.yaml
# Creating COLLABORATOR certificate key pair with following settings: CN=2, SAN=DNS:2
#   Moving COLLABORATOR certificate to: /home/shivam/Documents/Gatech_Coursework/Semester 2/AIC/Final Project/git/AIC_Project_Final_Notebooks/OpenFl/cert/col_2
# The CSR Hash for file col_2.csr = ac20670bbed637e1811706eadc6fb37618faa36074f9ca52749f78b38898c862b1a55ad82e2c00cd1b94e392c4006373
#  Signing COLLABORATOR certificate
#
# Registering 2 in /home/shivam/.local/workspace/plan/cols.yaml
# Creating COLLABORATOR certificate key pair with following settings: CN=3, SAN=DNS:3
#   Moving COLLABORATOR certificate to: /home/shivam/Documents/Gatech_Coursework/Semester 2/AIC/Final Project/git/AIC_Project_Final_Notebooks/OpenFl/cert/col_3
# The CSR Hash for file col_3.csr = 09e99c3d4f985fdd5f7eac919494286fe91eced2dc6832353fae52f976d3a4ed450e96cc07ed79f002cbb60391e7e4f5
#  Signing COLLABORATOR certificate
#
# Registering 3 in /home/shivam/.local/workspace/plan/cols.yaml
# Creating COLLABORATOR certificate key pair with following settings: CN=4, SAN=DNS:4
#   Moving COLLABORATOR certificate to: /home/shivam/Documents/Gatech_Coursework/Semester 2/AIC/Final Project/git/AIC_Project_Final_Notebooks/OpenFl/cert/col_4
# The CSR Hash for file col_4.csr = 7c92841c700939c4bfa4b4d23820a47633769ec0bfaac9623704e407472b58d2965837fd920d2c69affd6610de0043cb
#  Signing COLLABORATOR certificate
#
# Registering 4 in /home/shivam/.local/workspace/plan/cols.yaml

# %%
final_fl_model = fx.run_experiment(experiment_collaborators, override_config={"aggregator.settings.rounds_to_train": 20})
# Out:
# [23:54:53] INFO     Updating aggregator.settings.rounds_to_train to 20...                                                                          ]8;id=85734;file:///usr/local/lib/python3.8/dist-packages/openfl/native/native.py\native.py]8;;\:]8;id=432096;file:///usr/local/lib/python3.8/dist-packages/openfl/native/native.py#102\102]8;;\
#            INFO     FL-Plan hash is 164df001446fef577a3b2260bf97e83d497b8dbb4f803517902d39a10a643455d3c3e3e1532b03055d7385aed6ebf7ba                 ]8;id=314766;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=821512;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#235\235]8;;\
#            INFO     Building 🡆 Object NoCompressionPipeline from openfl.pipelines Module.                                                            ]8;id=230326;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=625922;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Creating Initial Weights File    🠆 save/torch_cnn_mnist_init.pbuf                                                              ]8;id=585326;file:///usr/local/lib/python3.8/dist-packages/openfl/native/native.py\native.py]8;;\:]8;id=720669;file:///usr/local/lib/python3.8/dist-packages/openfl/native/native.py#277\277]8;;\
#            INFO     Starting Experiment...                                                                                                         ]8;id=340358;file:///usr/local/lib/python3.8/dist-packages/openfl/native/native.py\native.py]8;;\:]8;id=180145;file:///usr/local/lib/python3.8/dist-packages/openfl/native/native.py#281\281]8;;\
#            INFO     Building 🡆 Object RandomGroupedAssigner from openfl.component Module.                                                            ]8;id=867426;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=634117;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Building 🡆 Object CutoffTimeBasedStragglerHandling from openfl.component.straggler_handling_functions Module.                    ]8;id=729465;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=207394;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Importing 🡆 Object write_metric from src.mnist_utils Module.                                                                     ]8;id=549886;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=413166;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#199\199]8;;\
#            INFO     Building 🡆 Object Aggregator from openfl.component Module.                                                                       ]8;id=825031;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=498743;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Using custom log metric: <function write_metric at 0x7f9de9e629d0>                                                          ]8;id=219599;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=288050;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#97\97]8;;\
#            INFO     Building 🡆 Object Collaborator from openfl.component Module.                                                                     ]8;id=553972;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=476064;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Building 🡆 Object Collaborator from openfl.component Module.                                                                     ]8;id=896557;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=421390;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Building 🡆 Object Collaborator from openfl.component Module.                                                                     ]8;id=868359;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=207191;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Building 🡆 Object Collaborator from openfl.component Module.                                                                     ]8;id=562949;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=527661;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Building 🡆 Object Collaborator from openfl.component Module.                                                                     ]8;id=199204;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=488776;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Waiting for tasks...                                                                                                     ]8;id=881463;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=379802;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#178\178]8;;\
#            INFO     Sending tasks to collaborator 0 for round 0                                                                                ]8;id=641008;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=814477;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#329\329]8;;\
#            INFO     Received the following tasks: ['aggregated_model_validation', 'train', 'locally_tuned_model_validation']                 ]8;id=318847;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=819846;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#168\168]8;;\
# [23:54:54] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=327712;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=739102;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:284: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:199.)
#   new_state[k] = pt.from_numpy(tensor_dict.pop(k)).to(device)
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [23:54:58] METRIC   Round 0, collaborator 0 is sending metric for task aggregated_model_validation: acc     0.095890                         ]8;id=465265;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=646215;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 0 is sending task results for aggregated_model_validation, round 0                                            ]8;id=341491;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=708828;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_agg aggregated_model_validation result acc:      0.095890                                   ]8;id=650516;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=552986;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=122124;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=706161;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
#            INFO     Run 0 epoch of 0 round                                                                                                      ]8;id=930879;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py\runner_pt.py]8;;\:]8;id=76918;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py#155\155]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [23:54:59] METRIC   Round 0, collaborator 0 is sending metric for task train: cross_entropy 0.455740                                         ]8;id=682799;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=96761;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 0 is sending task results for train, round 0                                                                  ]8;id=209567;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=195379;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator metric train result cross_entropy:        0.455740                                                   ]8;id=982680;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=98623;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=568352;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=510682;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 0 is sending metric for task locally_tuned_model_validation: acc  0.500000                         ]8;id=146166;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=433824;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 0 is sending task results for locally_tuned_model_validation, round 0                                         ]8;id=872875;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=411406;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_local locally_tuned_model_validation result acc: 0.500000                                   ]8;id=267891;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=935326;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     All tasks completed on 0 for round 0...                                                                                  ]8;id=599473;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=572589;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#171\171]8;;\
#            INFO     Waiting for tasks...                                                                                                     ]8;id=392229;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=1527;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#178\178]8;;\
#            INFO     Sending tasks to collaborator 1 for round 0                                                                                ]8;id=686815;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=306776;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#329\329]8;;\
#            INFO     Received the following tasks: ['aggregated_model_validation', 'train', 'locally_tuned_model_validation']                 ]8;id=954597;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=875147;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#168\168]8;;\
# [23:55:00] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=631965;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=309074;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 1 is sending metric for task aggregated_model_validation: acc     0.068493                         ]8;id=705534;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=821085;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 1 is sending task results for aggregated_model_validation, round 0                                            ]8;id=682192;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=110905;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_agg aggregated_model_validation result acc:      0.068493                                   ]8;id=251358;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=204070;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=28139;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=177419;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
#            INFO     Run 0 epoch of 0 round                                                                                                      ]8;id=185954;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py\runner_pt.py]8;;\:]8;id=144898;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py#155\155]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [23:55:01] METRIC   Round 0, collaborator 1 is sending metric for task train: cross_entropy 0.454653                                         ]8;id=157349;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=670758;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 1 is sending task results for train, round 0                                                                  ]8;id=233761;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=85953;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator metric train result cross_entropy:        0.454653                                                   ]8;id=871586;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=996607;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
# [23:55:02] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=323968;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=238838;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 1 is sending metric for task locally_tuned_model_validation: acc  0.506849                         ]8;id=160285;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=590145;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 1 is sending task results for locally_tuned_model_validation, round 0                                         ]8;id=882118;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=459161;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_local locally_tuned_model_validation result acc: 0.506849                                   ]8;id=477173;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=263871;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     All tasks completed on 1 for round 0...                                                                                  ]8;id=984670;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=672170;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#171\171]8;;\
#            INFO     Waiting for tasks...                                                                                                     ]8;id=360346;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=283265;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#178\178]8;;\
#            INFO     Sending tasks to collaborator 2 for round 0                                                                                ]8;id=46952;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=260389;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#329\329]8;;\
#            INFO     Received the following tasks: ['aggregated_model_validation', 'train', 'locally_tuned_model_validation']                 ]8;id=564316;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=127969;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#168\168]8;;\
# [23:55:03] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=843423;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=421793;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 2 is sending metric for task aggregated_model_validation: acc     0.054795                         ]8;id=141583;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=997325;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 2 is sending task results for aggregated_model_validation, round 0                                            ]8;id=455598;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=115968;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_agg aggregated_model_validation result acc:      0.054795                                   ]8;id=507818;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=161358;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=842954;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=684372;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
#            INFO     Run 0 epoch of 0 round                                                                                                      ]8;id=308655;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py\runner_pt.py]8;;\:]8;id=762414;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py#155\155]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [23:55:04] METRIC   Round 0, collaborator 2 is sending metric for task train: cross_entropy 0.452022                                         ]8;id=775932;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=492847;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 2 is sending task results for train, round 0                                                                  ]8;id=653136;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=754908;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator metric train result cross_entropy:        0.452022                                                   ]8;id=244547;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=919298;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=290827;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=634526;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 2 is sending metric for task locally_tuned_model_validation: acc  0.520548                         ]8;id=714569;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=145106;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 2 is sending task results for locally_tuned_model_validation, round 0                                         ]8;id=881951;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=728323;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_local locally_tuned_model_validation result acc: 0.520548                                   ]8;id=582546;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=573611;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     All tasks completed on 2 for round 0...                                                                                  ]8;id=367786;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=116418;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#171\171]8;;\
#            INFO     Waiting for tasks...                                                                                                     ]8;id=225649;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=204446;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#178\178]8;;\
#            INFO     Sending tasks to collaborator 3 for round 0                                                                                ]8;id=167491;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=829261;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#329\329]8;;\
#            INFO     Received the following tasks: ['aggregated_model_validation', 'train', 'locally_tuned_model_validation']                 ]8;id=90599;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=420980;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#168\168]8;;\
# [23:55:05] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=272321;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=60853;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 3 is sending metric for task aggregated_model_validation: acc     0.082759                         ]8;id=397904;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=297594;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 3 is sending task results for aggregated_model_validation, round 0                                            ]8;id=798893;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=635468;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_agg aggregated_model_validation result acc:      0.082759                                   ]8;id=937175;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=882075;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=50912;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=726286;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
#            INFO     Run 0 epoch of 0 round                                                                                                      ]8;id=22129;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py\runner_pt.py]8;;\:]8;id=890371;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py#155\155]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [23:55:06] METRIC   Round 0, collaborator 3 is sending metric for task train: cross_entropy 0.455929                                         ]8;id=533413;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=772775;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 3 is sending task results for train, round 0                                                                  ]8;id=532479;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=926293;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator metric train result cross_entropy:        0.455929                                                   ]8;id=126288;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=261700;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
# [23:55:07] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=381550;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=862756;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 3 is sending metric for task locally_tuned_model_validation: acc  0.462069                         ]8;id=585626;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=249817;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 3 is sending task results for locally_tuned_model_validation, round 0                                         ]8;id=139407;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=964354;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_local locally_tuned_model_validation result acc: 0.462069                                   ]8;id=304866;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=554707;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     All tasks completed on 3 for round 0...                                                                                  ]8;id=563334;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=63894;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#171\171]8;;\
#            INFO     Waiting for tasks...                                                                                                     ]8;id=809045;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=967570;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#178\178]8;;\
#            INFO     Sending tasks to collaborator 4 for round 0                                                                                ]8;id=349712;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=257510;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#329\329]8;;\
#            INFO     Received the following tasks: ['aggregated_model_validation', 'train', 'locally_tuned_model_validation']                 ]8;id=28890;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=950400;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#168\168]8;;\
# [23:55:08] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=397629;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=530932;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 4 is sending metric for task aggregated_model_validation: acc     0.048276                         ]8;id=955789;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=527288;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 4 is sending task results for aggregated_model_validation, round 0                                            ]8;id=420110;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=650219;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_agg aggregated_model_validation result acc:      0.048276                                   ]8;id=721277;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=727504;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=145267;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=406676;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
#            INFO     Run 0 epoch of 0 round                                                                                                      ]8;id=647122;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py\runner_pt.py]8;;\:]8;id=658930;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py#155\155]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [23:55:09] METRIC   Round 0, collaborator 4 is sending metric for task train: cross_entropy 0.453616                                         ]8;id=442897;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=592157;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 4 is sending task results for train, round 0                                                                  ]8;id=493099;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=989504;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator metric train result cross_entropy:        0.453616                                                   ]8;id=489931;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=671034;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=472481;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=990481;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 4 is sending metric for task locally_tuned_model_validation: acc  0.462069                         ]8;id=544840;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=689845;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 4 is sending task results for locally_tuned_model_validation, round 0                                         ]8;id=666955;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=116021;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_local locally_tuned_model_validation result acc: 0.462069                                   ]8;id=411379;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=547128;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            METRIC   Round 0, aggregator: locally_tuned_model_validation                                                                        ]8;id=585307;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=710570;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#842\842]8;;\
#                     <openfl.interface.aggregation_functions.weighted_average.WeightedAverage object at 0x7f9e1c289130> acc:     0.490385
#            METRIC   Round 0, aggregator: aggregated_model_validation <openfl.interface.aggregation_functions.weighted_average.WeightedAverage  ]8;id=447764;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=299150;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#842\842]8;;\
#                     object at 0x7f9e1c289130> acc:        0.070055
#            METRIC   Round 0: saved the best model with score 0.070055                                                                          ]8;id=539175;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=458371;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#858\858]8;;\
# [23:55:10] METRIC   Round 0, aggregator: train <openfl.interface.aggregation_functions.weighted_average.WeightedAverage object at              ]8;id=21574;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=410326;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#842\842]8;;\
#                     0x7f9e1c289130> cross_entropy:    0.454392
# [23:55:13] INFO     Saving round 1 model...                                                                                                    ]8;id=174195;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=263854;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#894\894]8;;\
#            INFO     Starting round 1...                                                                                                        ]8;id=934259;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=346277;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#901\901]8;;\
#            INFO     All tasks completed on 4 for round 0...                                                                                  ]8;id=218002;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=218158;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#171\171]8;;\
#            INFO     Waiting for tasks...                                                                                                     ]8;id=31337;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=273723;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#178\178]8;;\
#            INFO     Sending tasks to collaborator 0 for round 1                                                                                ]8;id=841700;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=323096;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#329\329]8;;\
#            INFO     Received the following tasks: ['aggregated_model_validation', 'train', 'locally_tuned_model_validation']                 ]8;id=404978;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=810522;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#168\168]8;;\
# [23:55:14] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=172062;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=71717;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 1, collaborator 0 is sending metric for task aggregated_model_validation: acc     0.500000                         ]8;id=517946;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=397051;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
# ...
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [00:03:08] METRIC   Round 19, collaborator 3 is sending metric for task aggregated_model_validation: acc    0.675862                         ]8;id=488581;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=968374;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 3 is sending task results for aggregated_model_validation, round 19                                           ]8;id=302216;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=240634;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 19, collaborator validate_agg aggregated_model_validation result acc:     0.675862                                   ]8;id=652216;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=267076;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
# [00:03:09] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=64611;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=997433;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
#            INFO     Run 0 epoch of 19 round                                                                                                     ]8;id=901515;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py\runner_pt.py]8;;\:]8;id=798390;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py#155\155]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 19, collaborator 3 is sending metric for task train: cross_entropy        0.334081                                 ]8;id=39337;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=678612;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 3 is sending task results for train, round 19                                                                 ]8;id=110605;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=384023;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 19, collaborator metric train result cross_entropy:       0.334081                                                   ]8;id=576247;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=253031;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
# [00:03:10] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=849582;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=198156;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [00:03:11] METRIC   Round 19, collaborator 3 is sending metric for task locally_tuned_model_validation: acc 0.675862                         ]8;id=598728;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=482732;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 3 is sending task results for locally_tuned_model_validation, round 19                                        ]8;id=475158;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=470460;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 19, collaborator validate_local locally_tuned_model_validation result acc:        0.675862                           ]8;id=291264;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=110250;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     All tasks completed on 3 for round 19...                                                                                 ]8;id=848224;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=829937;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#171\171]8;;\
#            INFO     Waiting for tasks...                                                                                                     ]8;id=564072;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=325236;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#178\178]8;;\
#            INFO     Sending tasks to collaborator 4 for round 19                                                                               ]8;id=25110;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=561720;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#329\329]8;;\
#            INFO     Received the following tasks: ['aggregated_model_validation', 'train', 'locally_tuned_model_validation']                 ]8;id=185910;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=111676;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#168\168]8;;\
# [00:03:13] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=345070;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=93640;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 19, collaborator 4 is sending metric for task aggregated_model_validation: acc    0.710345                         ]8;id=450949;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=642900;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 4 is sending task results for aggregated_model_validation, round 19                                           ]8;id=163365;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=281620;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 19, collaborator validate_agg aggregated_model_validation result acc:     0.710345                                   ]8;id=373304;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=389277;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
# [00:03:14] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=382906;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=68843;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
#            INFO     Run 0 epoch of 19 round                                                                                                     ]8;id=501144;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py\runner_pt.py]8;;\:]8;id=666129;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py#155\155]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [00:03:15] METRIC   Round 19, collaborator 4 is sending metric for task train: cross_entropy        0.331846                                 ]8;id=95008;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=987465;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 4 is sending task results for train, round 19                                                                 ]8;id=115033;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=12987;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 19, collaborator metric train result cross_entropy:       0.331846                                                   ]8;id=708185;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=37910;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
# [00:03:16] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=20416;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=710418;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 19, collaborator 4 is sending metric for task locally_tuned_model_validation: acc 0.710345                         ]8;id=639683;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=605322;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 4 is sending task results for locally_tuned_model_validation, round 19                                        ]8;id=162994;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=113623;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 19, collaborator validate_local locally_tuned_model_validation result acc:        0.710345                           ]8;id=170975;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=470978;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            METRIC   Round 19, aggregator: locally_tuned_model_validation                                                                       ]8;id=824473;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=519593;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#842\842]8;;\
#                     <openfl.interface.aggregation_functions.weighted_average.WeightedAverage object at 0x7f9e1c289130> acc:    0.699176
#            METRIC   Round 19, aggregator: aggregated_model_validation <openfl.interface.aggregation_functions.weighted_average.WeightedAverage ]8;id=503232;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=45298;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#842\842]8;;\
#                     object at 0x7f9e1c289130> acc:       0.699176
#            METRIC   Round 19: saved the best model with score 0.699176                                                                         ]8;id=733656;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=501716;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#858\858]8;;\
# [00:03:17] METRIC   Round 19, aggregator: train <openfl.interface.aggregation_functions.weighted_average.WeightedAverage object at             ]8;id=293221;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=685302;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#842\842]8;;\
#                     0x7f9e1c289130> cross_entropy:   0.337919
# [00:03:21] INFO     Saving round 20 model...                                                                                                   ]8;id=389351;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=176948;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#894\894]8;;\
# [00:03:22] INFO     Experiment Completed. Cleaning up...                                                                                       ]8;id=731927;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=57441;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#899\899]8;;\
#            INFO     All tasks completed on 4 for round 19...                                                                                 ]8;id=316960;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=664671;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#171\171]8;;\

# %% [markdown]
# We get a model with validation score = 67% ( for 2 clients)
# We get a model with validation score = 55% ( 3 epochs, 5 clients)
