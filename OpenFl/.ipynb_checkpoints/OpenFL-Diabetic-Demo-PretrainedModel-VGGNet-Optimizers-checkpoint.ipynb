# %% [markdown]
# # FedProx Optimizers

# %%
import openfl.native as fx
from openfl.federated import FederatedModel, FederatedDataSet

# %% [markdown]
# ## Load Dataset and Transfer
# ### Define Torch Dataloader

# %%
from openfl.federated import FederatedModel,FederatedDataSet

from openfl.utilities.data_splitters import DirichletNumPyDataSplitter
from openfl.utilities.data_splitters import EqualNumPyDataSplitter
from openfl.utilities.data_splitters import LogNormalNumPyDataSplitter
from openfl.utilities.data_splitters import RandomNumPyDataSplitter

import DataSplitterMethods
data_splitter = DataSplitterMethods.SplitFunctionGenerator("1-Class-per-collab-split")

import torch
import torchvision
from torchvision import transforms
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

## Replace here with path of your folder. 
dataset = torchvision.datasets.ImageFolder(root='/home/shivam/Documents/Gatech_Coursework/Semester 2/AIC/Final Project/content/gaussian_filtered_images/gaussian_filtered_images', transform=transform)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True, num_workers=4)

# %% [markdown]
# ### Display data into train and valid sets

# %%
import matplotlib.pyplot as plt
import numpy as np

def index_to_class_name(index, dataset):
    return dataset.classes[index]

len_images = 10
images, labels = next(iter(dataloader))
sample_indices = np.random.choice(len(images), len_images, replace=False)
sample_images = images[sample_indices]
sample_labels = labels[sample_indices]

for i, image in enumerate(sample_images):
    class_name = index_to_class_name(sample_labels[i], dataset)
    plt.subplot(2, 5, i+1)
    plt.imshow(image.permute(1, 2, 0))
    plt.title(class_name)
    plt.axis('off')

plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Distribute data into train and valid data sets

# %%
data_loader = torch.utils.data.DataLoader(dataset, batch_size=len(dataset), shuffle=False)
data, labels = next(iter(data_loader))
print("The data shape is {}".format(data.shape))
# Out:
# The data shape is torch.Size([3662, 3, 224, 224])

# %%
import torch.nn.functional as F
def split_and_return_train_valid(data, labels, split = 0.2):
  test_indices = np.random.rand(data.shape[0]) < split
  train_indices = ~test_indices
  train_data, test_data = data[train_indices], data[test_indices]
  train_labels, test_labels = labels[train_indices], labels[test_indices]
  train_labels, test_labels = F.one_hot(train_labels), F.one_hot(test_labels)
  return train_data, train_labels, test_data, test_labels

train_data, train_labels, test_data, test_labels = split_and_return_train_valid(data, labels) 
print("Train Data Length is {}".format(len(train_data)))
print("Test Data Length is {}".format(len(test_data)))
# Out:
# Train Data Length is 2946
# Test Data Length is 716

# %%
from openfl.federated import FederatedModel,FederatedDataSet
batch_size = 16
num_classes = 5
fl_data = FederatedDataSet(train_data, train_labels, test_data, test_labels, 
                           batch_size = batch_size , num_classes = num_classes, train_splitter = data_splitter)

# %% [markdown]
# ###  Define Model - Pretrained Model
# We can use a pretrained model like Inception or VGG Net to perform classification. These have already been pretrained on large-scale image data and we need to train only some final linear layers.

# %%
from openfl.utilities.optimizers.torch import FedProxOptimizer

import torch
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim


class Net(nn.Module):
    def __init__(self, num_classes=5):
        super(Net, self).__init__()
        self.num_classes = num_classes
        self.inception = models.googlenet(pretrained=True)
        
        for param in self.inception.parameters():
            param.requires_grad = False
            
        self.inception.fc = nn.Linear(self.inception.fc.in_features, num_classes)

    def forward(self, x):
        x = self.inception(x)
        return F.log_softmax(x, dim=1)
    
    def train_epoch(self, batch_generator):
        from openfl.federated.task import PyTorchTaskRunner
        self.optimizer.set_old_weights([p for p in self.parameters()])
        return PyTorchTaskRunner.train_epoch(self, batch_generator)

    
optimizer = lambda x: FedProxOptimizer(x, lr=1e-3, mu=0.1)

def cross_entropy(output, target):
    """Binary cross-entropy metric
    """
    return F.binary_cross_entropy_with_logits(input=output,target=target.float())

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

count_parameters(Net())

## Earlier Parameters: 51386181
# Out:
# /home/shivam/.local/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/shivam/.local/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=GoogLeNet_Weights.IMAGENET1K_V1`. You can also use `weights=GoogLeNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 5125

# %%
net = Net()
net(data[3:8]).shape
# Out:
# torch.Size([5, 5])

# %%
fl_model = FederatedModel(build_model=Net, optimizer=optimizer, loss_fn=cross_entropy, data_loader=fl_data)
# Out:
# tried to remove tensor: __opt_state_needed not present in the tensor dict

# %% [markdown]
# ### Define OpenFlow Plan

# %%
NUM_COLLABORATORS = 5
collaborator_list = [str(i) for i in range(NUM_COLLABORATORS)]
experiment_collaborators = {col_name:col_model for col_name, col_model \
                                 in zip(collaborator_list, fl_model.setup(len(collaborator_list)))}
# Out:
# tried to remove tensor: __opt_state_needed not present in the tensor dict
# tried to remove tensor: __opt_state_needed not present in the tensor dict
# tried to remove tensor: __opt_state_needed not present in the tensor dict
# tried to remove tensor: __opt_state_needed not present in the tensor dict
# tried to remove tensor: __opt_state_needed not present in the tensor dict

# %%
fx.init('torch_cnn_mnist', col_names=collaborator_list)
# Out:
# Creating Workspace Directories
# Creating Workspace Templates
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch==1.13.1 in /home/shivam/.local/lib/python3.8/site-packages (from -r /home/shivam/.local/workspace/requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: torchvision==0.14.1 in /home/shivam/.local/lib/python3.8/site-packages (from -r /home/shivam/.local/workspace/requirements.txt (line 2)) (0.14.1)
# Requirement already satisfied: tensorboard in /home/shivam/.local/lib/python3.8/site-packages (from -r /home/shivam/.local/workspace/requirements.txt (line 3)) (2.8.0)
# Requirement already satisfied: wheel>=0.38.0 in /home/shivam/.local/lib/python3.8/site-packages (from -r /home/shivam/.local/workspace/requirements.txt (line 4)) (0.40.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.8/dist-packages (from torch==1.13.1->-r /home/shivam/.local/workspace/requirements.txt (line 1)) (11.7.99)
# Requirement already satisfied: typing-extensions in /home/shivam/.local/lib/python3.8/site-packages (from torch==1.13.1->-r /home/shivam/.local/workspace/requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.8/dist-packages (from torch==1.13.1->-r /home/shivam/.local/workspace/requirements.txt (line 1)) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.8/dist-packages (from torch==1.13.1->-r /home/shivam/.local/workspace/requirements.txt (line 1)) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.8/dist-packages (from torch==1.13.1->-r /home/shivam/.local/workspace/requirements.txt (line 1)) (11.10.3.66)
# Requirement already satisfied: numpy in /home/shivam/.local/lib/python3.8/site-packages (from torchvision==0.14.1->-r /home/shivam/.local/workspace/requirements.txt (line 2)) (1.22.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/shivam/.local/lib/python3.8/site-packages (from torchvision==0.14.1->-r /home/shivam/.local/workspace/requirements.txt (line 2)) (9.4.0)
# Requirement already satisfied: requests in /home/shivam/.local/lib/python3.8/site-packages (from torchvision==0.14.1->-r /home/shivam/.local/workspace/requirements.txt (line 2)) (2.28.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->-r /home/shivam/.local/workspace/requirements.txt (line 1)) (45.2.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: protobuf>=3.6.0 in /home/shivam/.local/lib/python3.8/site-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (3.20.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/shivam/.local/lib/python3.8/site-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (3.4.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/shivam/.local/lib/python3.8/site-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (1.8.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (1.48.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (2.17.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/shivam/.local/lib/python3.8/site-packages (from tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (1.14.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/shivam/.local/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (4.12.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->torchvision==0.14.1->-r /home/shivam/.local/workspace/requirements.txt (line 2)) (2.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/shivam/.local/lib/python3.8/site-packages (from requests->torchvision==0.14.1->-r /home/shivam/.local/workspace/requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/shivam/.local/lib/python3.8/site-packages (from requests->torchvision==0.14.1->-r /home/shivam/.local/workspace/requirements.txt (line 2)) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->torchvision==0.14.1->-r /home/shivam/.local/workspace/requirements.txt (line 2)) (2019.11.28)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/shivam/.local/lib/python3.8/site-packages (from werkzeug>=0.11.15->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/shivam/.local/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r /home/shivam/.local/workspace/requirements.txt (line 3)) (3.1.0)
# Successfully installed packages from /home/shivam/.local/workspace/requirements.txt.
#
# New workspace directory structure:
# workspace
# ├── envoy_config.yaml
# ├── cert
# ├── test_output
# ├── agg_to_col_3_signed_cert.zip
# ├── spam_metric.log
# ├── agg_to_col_1_signed_cert.zip
# ├── agg_to_col_4_signed_cert.zip
# ├── shard_descriptor.py
# ├── save
# │   ├── torch_cnn_mnist_init.pbuf
# │   ├── keras_cnn_mnist_init.pbuf
# │   ├── torch_cnn_mnist_last.pbuf
# │   └── torch_cnn_mnist_best.pbuf
# ├── logs
# │   └── cnn_mnist
# │       ├── events.out.tfevents.1681513600.Roger.50728.0
# │       ├── events.out.tfevents.1681315750.Roger.48608.0
# │       ├── events.out.tfevents.1681536248.Roger.66960.0
# │       ├── events.out.tfevents.1681431847.Roger.17954.0
# │       ├── events.out.tfevents.1681593468.Roger.13993.0
# │       ├── events.out.tfevents.1681434736.Roger.21857.0
# │       ├── events.out.tfevents.1681589220.Roger.7572.0
# │       ├── events.out.tfevents.1681514476.Roger.52085.0
# │       ├── events.out.tfevents.1681599531.Roger.10613.0
# │       ├── events.out.tfevents.1681599867.Roger.19581.0
# │       ├── events.out.tfevents.1681512387.Roger.43871.0
# │       ├── events.out.tfevents.1681519569.Roger.59873.0
# │       ├── events.out.tfevents.1681269401.Roger.8557.0
# │       ├── events.out.tfevents.1681530898.Roger.63326.0
# │       ├── events.out.tfevents.1681442737.Roger.16494.0
# │       ├── events.out.tfevents.1681500355.Roger.36072.0
# │       ├── events.out.tfevents.1681504902.Roger.43395.0
# │       ├── events.out.tfevents.1681433866.Roger.20887.0
# │       ├── events.out.tfevents.1681518873.Roger.58996.0
# │       ├── events.out.tfevents.1681433027.Roger.19981.0
# │       ├── events.out.tfevents.1681269659.Roger.9184.0
# │       ├── events.out.tfevents.1681514439.Roger.43369.0
# │       ├── events.out.tfevents.1681270907.Roger.12430.0
# │       ├── events.out.tfevents.1681515196.Roger.52877.0
# │       ├── events.out.tfevents.1681442137.Roger.16260.0
# │       ├── events.out.tfevents.1681516050.Roger.55083.0
# │       ├── events.out.tfevents.1681529604.Roger.62329.0
# │       ├── events.out.tfevents.1681591569.Roger.10588.0
# │       ├── events.out.tfevents.1681431623.Roger.15620.0
# │       ├── events.out.tfevents.1681534507.Roger.65911.0
# │       ├── events.out.tfevents.1680565291.Roger.63976.0
# │       ├── events.out.tfevents.1681431104.Roger.15376.0
# │       ├── events.out.tfevents.1681431169.Roger.15821.0
# │       ├── events.out.tfevents.1681530171.Roger.62643.0
# │       ├── events.out.tfevents.1681531599.Roger.64636.0
# │       ├── events.out.tfevents.1681512958.Roger.50296.0
# │       ├── events.out.tfevents.1681270134.Roger.10870.0
# │       ├── events.out.tfevents.1681535616.Roger.66591.0
# │       ├── events.out.tfevents.1681438729.Roger.8889.0
# │       ├── events.out.tfevents.1681267520.Roger.21655.0
# │       ├── events.out.tfevents.1681596228.Roger.17915.0
# │       ├── events.out.tfevents.1681431926.Roger.18157.0
# │       ├── events.out.tfevents.1680564705.Roger.56398.2
# │       ├── events.out.tfevents.1681595013.Roger.17020.0
# │       ├── events.out.tfevents.1681517475.Roger.57469.0
# │       ├── events.out.tfevents.1681434171.Roger.21460.0
# │       ├── events.out.tfevents.1680564647.Roger.56398.1
# │       ├── events.out.tfevents.1681431293.Roger.16283.0
# │       ├── events.out.tfevents.1681598935.Roger.19195.0
# │       ├── events.out.tfevents.1681536991.Roger.67520.0
# │       ├── events.out.tfevents.1681437192.Roger.21359.0
# │       ├── events.out.tfevents.1681435916.Roger.22846.0
# │       ├── events.out.tfevents.1681595592.Roger.17407.0
# │       ├── events.out.tfevents.1681501080.Roger.37298.0
# │       ├── events.out.tfevents.1681432490.Roger.19002.0
# │       ├── events.out.tfevents.1681431373.Roger.16522.0
# │       ├── events.out.tfevents.1681518143.Roger.58198.0
# │       ├── events.out.tfevents.1681514126.Roger.51532.0
# │       ├── events.out.tfevents.1681271675.Roger.8617.0
# │       ├── events.out.tfevents.1681266567.Roger.17464.0
# │       ├── events.out.tfevents.1681431242.Roger.15109.0
# │       ├── events.out.tfevents.1681333861.Roger.6627.0
# │       ├── events.out.tfevents.1681533865.Roger.65574.0
# │       ├── events.out.tfevents.1681512812.Roger.47787.0
# │       ├── events.out.tfevents.1681437951.Roger.8909.0
# │       ├── events.out.tfevents.1681520185.Roger.52115.0
# │       ├── events.out.tfevents.1681516946.Roger.56642.0
# │       ├── events.out.tfevents.1681267303.Roger.19209.0
# │       ├── events.out.tfevents.1681440192.Roger.9897.0
# │       └── events.out.tfevents.1681590355.Roger.9719.0
# ├── director.yaml
# ├── agg_to_col_one_signed_cert.zip
# ├── src
# │   ├── pt_cnn.py
# │   ├── tfmnist_inmemory.py
# │   ├── mnist_utils.py
# │   ├── keras_cnn.py
# │   ├── __init__.py
# │   ├── ptmnist_inmemory.py
# │   └── __pycache__
# │       ├── __init__.cpython-38.pyc
# │       └── mnist_utils.cpython-38.pyc
# ├── agg_to_col_0_signed_cert.zip
# ├── agg_to_col_2_signed_cert.zip
# ├── .workspace
# ├── requirements.txt
# ├── data
# ├── plan
# │   ├── defaults
# │   ├── data.yaml
# │   ├── plan.yaml
# │   └── cols.yaml
# └── agg_to_col_two_signed_cert.zip
#
# 8 directories, 100 files
# Setting Up Certificate Authority...
#
# 1.  Create Root CA
# 1.1 Create Directories
# 1.2 Create Database
# 1.3 Create CA Request and Certificate
# 2.  Create Signing Certificate
# 2.1 Create Directories
# 2.2 Create Database
# 2.3 Create Signing Certificate CSR
# 2.4 Sign Signing Certificate CSR
# 3   Create Certificate Chain
#
# Done.
# Creating AGGREGATOR certificate key pair with following settings: CN=roger, SAN=DNS:roger
#   Writing AGGREGATOR certificate key pair to: /home/shivam/Documents/Gatech_Coursework/Semester 2/AIC/Final Project/git/AIC_Project_Final_Notebooks/OpenFl/cert/server
# The CSR Hash for file server/agg_roger.csr = 3e7aa5b9879cdecb05ec6f0504d31e838d29013988384eec408b87f86b1152785b209eca0941c203b58b89f17877fda3
#  Signing AGGREGATOR certificate
# Creating COLLABORATOR certificate key pair with following settings: CN=0, SAN=DNS:0
#   Moving COLLABORATOR certificate to: /home/shivam/Documents/Gatech_Coursework/Semester 2/AIC/Final Project/git/AIC_Project_Final_Notebooks/OpenFl/cert/col_0
# The CSR Hash for file col_0.csr = 11484b6ae8cc5d1b0f65188e6a29e57057400aa38297c96caa497f7a3b2c8924950fe7fe778c2adac617095c8da01c93
#  Signing COLLABORATOR certificate
#
# Registering 0 in /home/shivam/.local/workspace/plan/cols.yaml
# Creating COLLABORATOR certificate key pair with following settings: CN=1, SAN=DNS:1
#   Moving COLLABORATOR certificate to: /home/shivam/Documents/Gatech_Coursework/Semester 2/AIC/Final Project/git/AIC_Project_Final_Notebooks/OpenFl/cert/col_1
# The CSR Hash for file col_1.csr = 3f85fb96e1bc68e2996f973c456d8f29a1664ea1e4fdaae99d86e1ffd4acbaa45d436be525cfbdf82f4e09a35df58d80
#  Signing COLLABORATOR certificate
#
# Registering 1 in /home/shivam/.local/workspace/plan/cols.yaml
# Creating COLLABORATOR certificate key pair with following settings: CN=2, SAN=DNS:2
#   Moving COLLABORATOR certificate to: /home/shivam/Documents/Gatech_Coursework/Semester 2/AIC/Final Project/git/AIC_Project_Final_Notebooks/OpenFl/cert/col_2
# The CSR Hash for file col_2.csr = e96561423b388468b0358f838f062e654e0090badb0d707030a35eb11bceec2d9ef445e8b3298fc3ed0a50a65b998041
#  Signing COLLABORATOR certificate
#
# Registering 2 in /home/shivam/.local/workspace/plan/cols.yaml
# Creating COLLABORATOR certificate key pair with following settings: CN=3, SAN=DNS:3
#   Moving COLLABORATOR certificate to: /home/shivam/Documents/Gatech_Coursework/Semester 2/AIC/Final Project/git/AIC_Project_Final_Notebooks/OpenFl/cert/col_3
# The CSR Hash for file col_3.csr = 78fae303a4fb600409243054cd938b085ed335ac54d24dbdc8b7dcb1dbf90a8e962dac2885457a4a0cef88af983bcc36
#  Signing COLLABORATOR certificate
#
# Registering 3 in /home/shivam/.local/workspace/plan/cols.yaml
# Creating COLLABORATOR certificate key pair with following settings: CN=4, SAN=DNS:4
#   Moving COLLABORATOR certificate to: /home/shivam/Documents/Gatech_Coursework/Semester 2/AIC/Final Project/git/AIC_Project_Final_Notebooks/OpenFl/cert/col_4
# The CSR Hash for file col_4.csr = c546c22fbdd09467207eee85f1f3c538434dbce0cd58fb9367d49175551975f267971ed5365edb065d89a133c27c9a2f
#  Signing COLLABORATOR certificate
#
# Registering 4 in /home/shivam/.local/workspace/plan/cols.yaml

# %%
final_fl_model = fx.run_experiment(experiment_collaborators, override_config={"aggregator.settings.rounds_to_train": 20})
# Out:
# [19:16:03] INFO     Updating aggregator.settings.rounds_to_train to 20...                                                                          ]8;id=6292;file:///usr/local/lib/python3.8/dist-packages/openfl/native/native.py\native.py]8;;\:]8;id=873198;file:///usr/local/lib/python3.8/dist-packages/openfl/native/native.py#102\102]8;;\
#            INFO     FL-Plan hash is 164df001446fef577a3b2260bf97e83d497b8dbb4f803517902d39a10a643455d3c3e3e1532b03055d7385aed6ebf7ba                 ]8;id=498131;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=726110;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#235\235]8;;\
#            INFO     Building 🡆 Object NoCompressionPipeline from openfl.pipelines Module.                                                            ]8;id=141065;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=62521;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Creating Initial Weights File    🠆 save/torch_cnn_mnist_init.pbuf                                                              ]8;id=381036;file:///usr/local/lib/python3.8/dist-packages/openfl/native/native.py\native.py]8;;\:]8;id=973471;file:///usr/local/lib/python3.8/dist-packages/openfl/native/native.py#277\277]8;;\
#            INFO     Starting Experiment...                                                                                                         ]8;id=194004;file:///usr/local/lib/python3.8/dist-packages/openfl/native/native.py\native.py]8;;\:]8;id=929927;file:///usr/local/lib/python3.8/dist-packages/openfl/native/native.py#281\281]8;;\
#            INFO     Building 🡆 Object RandomGroupedAssigner from openfl.component Module.                                                            ]8;id=922631;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=577157;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Building 🡆 Object CutoffTimeBasedStragglerHandling from openfl.component.straggler_handling_functions Module.                    ]8;id=977563;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=290533;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Importing 🡆 Object write_metric from src.mnist_utils Module.                                                                     ]8;id=366591;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=641013;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#199\199]8;;\
#            INFO     Building 🡆 Object Aggregator from openfl.component Module.                                                                       ]8;id=585033;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=284948;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Using custom log metric: <function write_metric at 0x7f4a457e80d0>                                                          ]8;id=7170;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=367265;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#97\97]8;;\
# [19:16:04] INFO     Building 🡆 Object Collaborator from openfl.component Module.                                                                     ]8;id=474863;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=965738;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Building 🡆 Object Collaborator from openfl.component Module.                                                                     ]8;id=878332;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=971647;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Building 🡆 Object Collaborator from openfl.component Module.                                                                     ]8;id=291471;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=192086;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Building 🡆 Object Collaborator from openfl.component Module.                                                                     ]8;id=881422;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=849768;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Building 🡆 Object Collaborator from openfl.component Module.                                                                     ]8;id=665543;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py\plan.py]8;;\:]8;id=822070;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/plan/plan.py#171\171]8;;\
#            INFO     Waiting for tasks...                                                                                                     ]8;id=358538;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=305547;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#178\178]8;;\
#            INFO     Sending tasks to collaborator 0 for round 0                                                                                ]8;id=835018;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=364871;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#329\329]8;;\
#            INFO     Received the following tasks: ['aggregated_model_validation', 'train', 'locally_tuned_model_validation']                 ]8;id=318755;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=392788;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#168\168]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=851105;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=404650;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:284: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:199.)
#   new_state[k] = pt.from_numpy(tensor_dict.pop(k)).to(device)
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [19:16:08] METRIC   Round 0, collaborator 0 is sending metric for task aggregated_model_validation: acc     0.500000                         ]8;id=282302;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=201759;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 0 is sending task results for aggregated_model_validation, round 0                                            ]8;id=644157;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=69464;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_agg aggregated_model_validation result acc:      0.500000                                   ]8;id=325433;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=965063;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=810749;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=174345;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
#            INFO     Run 0 epoch of 0 round                                                                                                      ]8;id=792480;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py\runner_pt.py]8;;\:]8;id=646725;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py#155\155]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 0 is sending metric for task train: cross_entropy 0.473962                                         ]8;id=707717;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=823922;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 0 is sending task results for train, round 0                                                                  ]8;id=809955;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=720933;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
# [19:16:09] METRIC   Round 0, collaborator metric train result cross_entropy:        0.473962                                                   ]8;id=924172;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=465420;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=804864;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=991988;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 0 is sending metric for task locally_tuned_model_validation: acc  0.527778                         ]8;id=48658;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=439239;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 0 is sending task results for locally_tuned_model_validation, round 0                                         ]8;id=958453;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=910082;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_local locally_tuned_model_validation result acc: 0.527778                                   ]8;id=642786;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=22133;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     All tasks completed on 0 for round 0...                                                                                  ]8;id=825180;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=622099;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#171\171]8;;\
#            INFO     Waiting for tasks...                                                                                                     ]8;id=506483;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=309219;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#178\178]8;;\
#            INFO     Sending tasks to collaborator 1 for round 0                                                                                ]8;id=118925;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=855304;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#329\329]8;;\
#            INFO     Received the following tasks: ['aggregated_model_validation', 'train', 'locally_tuned_model_validation']                 ]8;id=632263;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=504596;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#168\168]8;;\
# [19:16:10] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=885469;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=895741;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 1 is sending metric for task aggregated_model_validation: acc     0.440559                         ]8;id=337841;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=141915;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 1 is sending task results for aggregated_model_validation, round 0                                            ]8;id=180226;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=457023;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_agg aggregated_model_validation result acc:      0.440559                                   ]8;id=473663;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=478226;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=525598;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=969572;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
#            INFO     Run 0 epoch of 0 round                                                                                                      ]8;id=356256;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py\runner_pt.py]8;;\:]8;id=791730;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py#155\155]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [19:16:11] METRIC   Round 0, collaborator 1 is sending metric for task train: cross_entropy 0.476337                                         ]8;id=925575;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=518134;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 1 is sending task results for train, round 0                                                                  ]8;id=769297;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=256640;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator metric train result cross_entropy:        0.476337                                                   ]8;id=289311;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=650465;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=155686;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=284290;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 1 is sending metric for task locally_tuned_model_validation: acc  0.489510                         ]8;id=873945;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=449090;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 1 is sending task results for locally_tuned_model_validation, round 0                                         ]8;id=889357;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=570898;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_local locally_tuned_model_validation result acc: 0.489510                                   ]8;id=843254;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=726322;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     All tasks completed on 1 for round 0...                                                                                  ]8;id=664456;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=949173;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#171\171]8;;\
#            INFO     Waiting for tasks...                                                                                                     ]8;id=695286;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=497045;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#178\178]8;;\
#            INFO     Sending tasks to collaborator 2 for round 0                                                                                ]8;id=142766;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=342753;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#329\329]8;;\
#            INFO     Received the following tasks: ['aggregated_model_validation', 'train', 'locally_tuned_model_validation']                 ]8;id=197693;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=546370;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#168\168]8;;\
# [19:16:12] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=576469;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=587312;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 2 is sending metric for task aggregated_model_validation: acc     0.468531                         ]8;id=447374;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=515288;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 2 is sending task results for aggregated_model_validation, round 0                                            ]8;id=577904;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=977712;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_agg aggregated_model_validation result acc:      0.468531                                   ]8;id=745940;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=443899;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
# [19:16:13] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=717457;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=634523;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
#            INFO     Run 0 epoch of 0 round                                                                                                      ]8;id=710010;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py\runner_pt.py]8;;\:]8;id=776817;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py#155\155]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 2 is sending metric for task train: cross_entropy 0.474404                                         ]8;id=23328;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=792624;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 2 is sending task results for train, round 0                                                                  ]8;id=858373;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=601648;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator metric train result cross_entropy:        0.474404                                                   ]8;id=79426;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=817802;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
# [19:16:14] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=372791;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=597022;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 2 is sending metric for task locally_tuned_model_validation: acc  0.538462                         ]8;id=966939;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=166172;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 2 is sending task results for locally_tuned_model_validation, round 0                                         ]8;id=252091;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=741330;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_local locally_tuned_model_validation result acc: 0.538462                                   ]8;id=550488;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=941661;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     All tasks completed on 2 for round 0...                                                                                  ]8;id=709240;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=864282;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#171\171]8;;\
#            INFO     Waiting for tasks...                                                                                                     ]8;id=919243;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=512673;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#178\178]8;;\
#            INFO     Sending tasks to collaborator 3 for round 0                                                                                ]8;id=506768;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=409218;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#329\329]8;;\
#            INFO     Received the following tasks: ['aggregated_model_validation', 'train', 'locally_tuned_model_validation']                 ]8;id=856256;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=552340;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#168\168]8;;\
# [19:16:15] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=271396;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=657735;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 3 is sending metric for task aggregated_model_validation: acc     0.433566                         ]8;id=203763;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=872416;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 3 is sending task results for aggregated_model_validation, round 0                                            ]8;id=832841;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=43932;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_agg aggregated_model_validation result acc:      0.433566                                   ]8;id=692857;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=546883;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=86149;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=275979;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
#            INFO     Run 0 epoch of 0 round                                                                                                      ]8;id=351708;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py\runner_pt.py]8;;\:]8;id=653475;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py#155\155]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [19:16:16] METRIC   Round 0, collaborator 3 is sending metric for task train: cross_entropy 0.474890                                         ]8;id=443612;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=445948;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 3 is sending task results for train, round 0                                                                  ]8;id=401012;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=650734;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator metric train result cross_entropy:        0.474890                                                   ]8;id=63869;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=986446;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=165327;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=327998;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 3 is sending metric for task locally_tuned_model_validation: acc  0.475524                         ]8;id=695750;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=814118;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 3 is sending task results for locally_tuned_model_validation, round 0                                         ]8;id=202129;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=198441;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_local locally_tuned_model_validation result acc: 0.475524                                   ]8;id=538486;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=496053;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     All tasks completed on 3 for round 0...                                                                                  ]8;id=197693;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=277871;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#171\171]8;;\
#            INFO     Waiting for tasks...                                                                                                     ]8;id=142592;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=567380;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#178\178]8;;\
#            INFO     Sending tasks to collaborator 4 for round 0                                                                                ]8;id=226510;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=165680;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#329\329]8;;\
#            INFO     Received the following tasks: ['aggregated_model_validation', 'train', 'locally_tuned_model_validation']                 ]8;id=635665;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=590134;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#168\168]8;;\
# [19:16:17] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=715640;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=706965;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 4 is sending metric for task aggregated_model_validation: acc     0.384615                         ]8;id=418098;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=585571;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 4 is sending task results for aggregated_model_validation, round 0                                            ]8;id=707155;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=73378;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_agg aggregated_model_validation result acc:      0.384615                                   ]8;id=77635;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=872651;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
# [19:16:18] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=730233;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=739214;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
#            INFO     Run 0 epoch of 0 round                                                                                                      ]8;id=38798;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py\runner_pt.py]8;;\:]8;id=773179;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py#155\155]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 4 is sending metric for task train: cross_entropy 0.475220                                         ]8;id=111520;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=388459;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 4 is sending task results for train, round 0                                                                  ]8;id=804054;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=780908;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator metric train result cross_entropy:        0.475220                                                   ]8;id=762119;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=220955;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
# [19:16:19] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=36051;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=842590;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 0, collaborator 4 is sending metric for task locally_tuned_model_validation: acc  0.475524                         ]8;id=145467;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=226499;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 4 is sending task results for locally_tuned_model_validation, round 0                                         ]8;id=174515;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=76584;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 0, collaborator validate_local locally_tuned_model_validation result acc: 0.475524                                   ]8;id=531543;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=247808;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            METRIC   Round 0, aggregator: locally_tuned_model_validation                                                                        ]8;id=468221;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=369146;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#842\842]8;;\
#                     <openfl.interface.aggregation_functions.weighted_average.WeightedAverage object at 0x7f4a28ce1b80> acc:     0.501397
#            METRIC   Round 0, aggregator: train <openfl.interface.aggregation_functions.weighted_average.WeightedAverage object at              ]8;id=563683;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=764527;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#842\842]8;;\
#                     0x7f4a28ce1b80> cross_entropy:    0.474963
# [19:16:22] METRIC   Round 0, aggregator: aggregated_model_validation <openfl.interface.aggregation_functions.weighted_average.WeightedAverage  ]8;id=707836;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=711474;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#842\842]8;;\
#                     object at 0x7f4a28ce1b80> acc:        0.445531
#            METRIC   Round 0: saved the best model with score 0.445531                                                                          ]8;id=775050;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=91203;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#858\858]8;;\
#            INFO     Saving round 1 model...                                                                                                    ]8;id=430440;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=918213;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#894\894]8;;\
#            INFO     Starting round 1...                                                                                                        ]8;id=114480;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=930820;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#901\901]8;;\
#            INFO     All tasks completed on 4 for round 0...                                                                                  ]8;id=734655;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=999753;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#171\171]8;;\
#            INFO     Waiting for tasks...                                                                                                     ]8;id=318164;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=808572;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#178\178]8;;\
#            INFO     Sending tasks to collaborator 0 for round 1                                                                                ]8;id=506455;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=461514;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#329\329]8;;\
#            INFO     Received the following tasks: ['aggregated_model_validation', 'train', 'locally_tuned_model_validation']                 ]8;id=894448;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=635204;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#168\168]8;;\
# [19:16:23] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=54286;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=830183;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 1, collaborator 0 is sending metric for task aggregated_model_validation: acc     0.527778                         ]8;id=920588;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=129004;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
# ...
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [19:23:53] METRIC   Round 19, collaborator 3 is sending metric for task aggregated_model_validation: acc    0.496503                         ]8;id=375205;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=180574;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 3 is sending task results for aggregated_model_validation, round 19                                           ]8;id=730445;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=351053;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 19, collaborator validate_agg aggregated_model_validation result acc:     0.496504                                   ]8;id=58225;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=287711;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     Using TaskRunner subclassing API                                                                                         ]8;id=247962;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=589065;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
#            INFO     Run 0 epoch of 19 round                                                                                                     ]8;id=426665;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py\runner_pt.py]8;;\:]8;id=375696;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py#155\155]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [19:23:54] METRIC   Round 19, collaborator 3 is sending metric for task train: cross_entropy        0.401720                                 ]8;id=854277;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=747270;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 3 is sending task results for train, round 19                                                                 ]8;id=964569;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=25342;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 19, collaborator metric train result cross_entropy:       0.401720                                                   ]8;id=937645;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=599098;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
# [19:23:55] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=557435;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=980013;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 19, collaborator 3 is sending metric for task locally_tuned_model_validation: acc 0.510490                         ]8;id=908779;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=59287;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 3 is sending task results for locally_tuned_model_validation, round 19                                        ]8;id=768821;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=747463;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 19, collaborator validate_local locally_tuned_model_validation result acc:        0.510490                           ]8;id=233549;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=637215;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            INFO     All tasks completed on 3 for round 19...                                                                                 ]8;id=999844;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=392802;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#171\171]8;;\
#            INFO     Waiting for tasks...                                                                                                     ]8;id=206573;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=326987;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#178\178]8;;\
#            INFO     Sending tasks to collaborator 4 for round 19                                                                               ]8;id=98565;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=760354;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#329\329]8;;\
#            INFO     Received the following tasks: ['aggregated_model_validation', 'train', 'locally_tuned_model_validation']                 ]8;id=806330;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=216966;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#168\168]8;;\
# [19:23:58] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=220438;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=223760;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 19, collaborator 4 is sending metric for task aggregated_model_validation: acc    0.517483                         ]8;id=6147;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=290143;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 4 is sending task results for aggregated_model_validation, round 19                                           ]8;id=974539;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=347740;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 19, collaborator validate_agg aggregated_model_validation result acc:     0.517483                                   ]8;id=758399;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=707072;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
# [19:23:59] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=765834;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=745670;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
#            INFO     Run 0 epoch of 19 round                                                                                                     ]8;id=327646;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py\runner_pt.py]8;;\:]8;id=344855;file:///usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py#155\155]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:458: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
#            METRIC   Round 19, collaborator 4 is sending metric for task train: cross_entropy        0.401892                                 ]8;id=619215;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=557416;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 4 is sending task results for train, round 19                                                                 ]8;id=831073;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=772366;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 19, collaborator metric train result cross_entropy:       0.401892                                                   ]8;id=108754;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=161979;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
# [19:24:00] INFO     Using TaskRunner subclassing API                                                                                         ]8;id=204040;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=657241;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#253\253]8;;\
# /usr/local/lib/python3.8/dist-packages/openfl/federated/task/runner_pt.py:107: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   data, target = pt.tensor(data).to(self.device), pt.tensor(
# [19:24:01] METRIC   Round 19, collaborator 4 is sending metric for task locally_tuned_model_validation: acc 0.531469                         ]8;id=205412;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=494099;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#415\415]8;;\
#            INFO     Collaborator 4 is sending task results for locally_tuned_model_validation, round 19                                        ]8;id=123807;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=287022;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#520\520]8;;\
#            METRIC   Round 19, collaborator validate_local locally_tuned_model_validation result acc:        0.531469                           ]8;id=411694;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=227499;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#559\559]8;;\
#            METRIC   Round 19, aggregator: locally_tuned_model_validation                                                                       ]8;id=463896;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=852670;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#842\842]8;;\
#                     <openfl.interface.aggregation_functions.weighted_average.WeightedAverage object at 0x7f4a28ce1b80> acc:    0.536313
#            METRIC   Round 19, aggregator: train <openfl.interface.aggregation_functions.weighted_average.WeightedAverage object at             ]8;id=362558;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=424709;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#842\842]8;;\
#                     0x7f4a28ce1b80> cross_entropy:   0.402123
# [19:24:05] METRIC   Round 19, aggregator: aggregated_model_validation <openfl.interface.aggregation_functions.weighted_average.WeightedAverage ]8;id=702951;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=452526;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#842\842]8;;\
#                     object at 0x7f4a28ce1b80> acc:       0.527933
#            METRIC   Round 19: saved the best model with score 0.527933                                                                         ]8;id=535670;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=342467;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#858\858]8;;\
#            INFO     Saving round 20 model...                                                                                                   ]8;id=320273;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=373989;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#894\894]8;;\
# [19:24:06] INFO     Experiment Completed. Cleaning up...                                                                                       ]8;id=439998;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py\aggregator.py]8;;\:]8;id=182999;file:///usr/local/lib/python3.8/dist-packages/openfl/component/aggregator/aggregator.py#899\899]8;;\
#            INFO     All tasks completed on 4 for round 19...                                                                                 ]8;id=15453;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py\collaborator.py]8;;\:]8;id=241398;file:///usr/local/lib/python3.8/dist-packages/openfl/component/collaborator/collaborator.py#171\171]8;;\

# %% [markdown]
# ## FedOpt optimizers
# Running the FedOpt Optimizers

# %%
from openfl.utilities.optimizers.torch import FedProxOptimizer

import torch
import torch.nn as nn
import torchvision.models as models
import torch.optim as optim


class FedOptNet(nn.Module):
    def __init__(self, num_classes=5):
        super(FedOptNet, self).__init__()
        self.num_classes = num_classes
        self.inception = models.googlenet(pretrained=True)
        
        for param in self.inception.parameters():
            param.requires_grad = False
            
        self.inception.fc = nn.Linear(self.inception.fc.in_features, num_classes)

    def forward(self, x):
        x = self.inception(x)
        return F.log_softmax(x, dim=1)
    
optimizer = lambda x: optim.Adam(x, lr=1e-4)

def cross_entropy(output, target):
    """Binary cross-entropy metric
    """
    return F.binary_cross_entropy_with_logits(input=output,target=target.float())

# %%
from openfl.interface.interactive_api.experiment import TaskInterface, ModelInterface
from openfl.interface.aggregation_functions import AdagradAdaptiveAggregation

framework_adapter = 'openfl.plugins.frameworks_adapters.pytorch_adapter.FrameworkAdapterPlugin'

TI = TaskInterface()
MI = ModelInterface(model=FedOptNet(),
                    optimizer=optimizer,
                    framework_plugin=framework_adapter)
...

# Creating aggregation function
agg_fn = AdagradAdaptiveAggregation(model_interface=MI,
                                    learning_rate=0.001)

# %%
fl_model = FederatedModel(build_model=FedOptNet, optimizer=optimizer, loss_fn=cross_entropy, data_loader=fl_data)

# %%
NUM_COLLABORATORS = 5
collaborator_list = [str(i) for i in range(NUM_COLLABORATORS)]
experiment_collaborators = {col_name:col_model for col_name, col_model \
                                 in zip(collaborator_list, fl_model.setup(len(collaborator_list)))}

# %%
fx.init('torch_cnn_mnist', col_names=collaborator_list)

# %%
final_fl_model = fx.run_experiment(experiment_collaborators, override_config={
    "aggregator.settings.rounds_to_train": 20, 
    'tasks.train.aggregation_type': agg_fn})
